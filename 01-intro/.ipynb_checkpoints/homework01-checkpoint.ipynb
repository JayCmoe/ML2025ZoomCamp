# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.2

# %%
import pandas as pd

data = pd.read_csv("datasets/car_fuel_efficiency.csv")
row_count = len(data) #9704
print(row_count)

num_of_rows = data.shape[0]
print(num_of_rows)
# Out:
# 9704
# 9704

# %%
df = data['fuel_type'].unique()
print(df)
# Out:
# ['Gasoline' 'Diesel']

# %%
print(data.columns)
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
print(data['engine_displacement'].isnull().sum()) #0
print(data['num_cylinders'].isnull().sum()) #482
print(data['horsepower'].isnull().sum()) #708
print(data['vehicle_weight'].isnull().sum()) #0
print(data['acceleration'].isnull().sum()) #930
print(data['model_year'].isnull().sum()) #0
print(data['origin'].isnull().sum()) #0
print(data['fuel_type'].isnull().sum()) #0
print(data['drivetrain'].isnull().sum()) #0
print(data['num_doors'].isnull().sum()) #502
print(data['fuel_efficiency_mpg'].isnull().sum()) #0

#4 Columns with missing values
# Out:
# 0
# 482
# 708
# 0
# 930
# 0
# 0
# 0
# 0
# 502
# 0

# %%
cars_from_asia = data[data['origin']=='Asia']
max_fuel_eff = cars_from_asia['fuel_efficiency_mpg'].max()
print(max_fuel_eff)
# Out:
# 23.759122836520497

# %%
print(data)
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
median_horsepower = data['horsepower'].median() #149.0
print(median_horsepower)
# Out:
# 149.0

# %%
mode_horsepower = data['horsepower'].mode() #152.0
print(mode_horsepower)
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
data['horsepower'] = data['horsepower'].fillna(152.0)
new_median_horsepower = data['horsepower'].median()
print(new_median_horsepower)
# Out:
# 152.0

# %%
print(data)
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
cars_from_asia = data[data['origin']=='Asia']
selected_columns = cars_from_asia[['vehicle_weight', 'model_year']]
first_n_rows = selected_columns.head(7)
print(first_n_rows)
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019

# %%
X = first_n_rows.to_numpy()
print(X)
# Out:
# [[2714.21930965 2016.        ]
#  [2783.86897424 2010.        ]
#  [3582.68736772 2007.        ]
#  [2231.8081416  2011.        ]
#  [2659.43145076 2016.        ]
#  [2844.22753389 2014.        ]
#  [3761.99403819 2019.        ]]

# %%
def vector_vector_multiplication(u, v):
    # Multiply each vector against second vector and sum total
    assert u.shape[0] == v.shape[0]

    n = u.shape[0]
    result = 0.0
    for i in range(n):
        result = result + u[i] * v[i]

    return result

# %%
def matrix_vector_multiplication(u, v):
    # Multiply each row in matrix against column vector and sum total
    assert u.shape[1] == v.shape[0]

    num_rows = u.shape[0]

    result = np.zeros(num_rows)

    for i in range(num_rows):
        result[i] = vector_vector_multiplication(u[i], v)

    return result

# %%
import numpy as np

def matrix_matrix_multiplication(u, v):
    assert u.shape[1] == v.shape[0]

    num_rows = u.shape[0]
    num_columns = v.shape[1]

    result = np.zeros((num_rows, num_columns))

    for i in range(num_columns):
        vi = v[:, i]
        uvi = matrix_vector_multiplication(u, vi)
        result[:, i] = uvi

    return result

# %%
XT = X.T
print(XT)
# Out:
# [[2714.21930965 2783.86897424 3582.68736772 2231.8081416  2659.43145076
#   2844.22753389 3761.99403819]
#  [2016.         2010.         2007.         2011.         2016.
#   2014.         2019.        ]]

# %%
XTX = np.dot(XT, X)
print(XTX)
# Out:
# [[62248334.33150762 41431216.5073268 ]
#  [41431216.5073268  28373339.        ]]

# %%
XTX_inv = np.linalg.inv(XTX)
print(XTX)
# Out:
# [[62248334.33150762 41431216.5073268 ]
#  [41431216.5073268  28373339.        ]]

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
print(y)
# Out:
# [1100 1300  800  900 1000 1100 1200]

# %%
"""Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w."""
# Out:
# 'Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.'

# %%
v = XTX_inv.dot(XT)
print(v)
# Out:
# [[-1.31202622e-04 -8.63909858e-05  3.72634923e-04 -4.02726650e-04
#   -1.62513724e-04 -5.52342829e-05  4.65094049e-04]
#  [ 2.62636846e-04  1.96990690e-04 -4.73392228e-04  6.58944477e-04
#    3.08357831e-04  1.51636137e-04 -6.07979633e-04]]

# %%
w = v.dot(y)
print(w)
print(w.sum())
# Out:
# [0.01386421 0.5049067 ]
# 0.5187709081074016
